# %% [markdown]
# <a href="https://colab.research.google.com/github/Farrukhbala/SSUET-AI-Assignments/blob/master/Numerical_Computing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 * 3.0
# Out:
# 6.0

# %%
2 + 3.0
# Out:
# 5.0

# %%
a = 0.0
for i in range(100000):
  a += 0.1

# %%
print(a)
# Out:
# 10000.000000018848

# %%
b = 10000

for i in range(100000):
  b -= 0.1

# %%
print(b)
# Out:
# -1.884864639367656e-08

# %%
c = 10000

for i in range(80000):
  c -= 0.125

# %%
print(c)
# Out:
# 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.5,1.5)
y = (5) * (np.sin(x)) ** 2 - (8)*(np.cos(x))**5

plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = [1,2,3,4,5,6,7,8,9]
x = [1,1,1,1.125,1.125,1.125,1.140625,1.1484375,1.15234375]
y = [2,1.5,1.25,1.25,1.1875,1.15625,1.15625,1.15625,1.15625]
z = [1.5,1.25,1.125,1.1875,1.15625,1.140625,1.1484375,1.15234375,1.154296875]
funcX = [-1,-1 ,-1 ,-0.201171875 ,-0.201171875 ,-0.201171875 ,-0.094142914 ,-0.0400033 ,-0.012775958]
funcY = [9, 2.875, 0.703125, 0.703125, 0.237060547, 0.014556885, 0.014556885, 0.014556885, 0.014556885]
funcZ = [2.875, 0.703125, -0.20117, 0.237061, 0.014557, -0.09414, -0.04, -0.01278, 0.000877]

plt.plot(t, x, t, y, t, z, t, funcX , t ,funcY , t , funcZ,linewidth=7.0)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = [1,2,3,4,5,6,7,8,9]

x = [1,1,1,1.125,1.125,1.125,1.140625,1.1484375,1.15234375]

y = [2,1.5,1.25,1.25,1.1875,1.15625,1.15625,1.15625,1.15625]

z = [1.5,1.25,1.125,1.1875,1.15625,1.140625,1.1484375,1.15234375,1.154296875]

funcX = [-1,-1 ,-1 ,-0.201171875 ,-0.201171875 ,-0.201171875 ,-0.094142914 ,-0.0400033 ,-0.012775958]

funcY = [9, 2.875, 0.703125, 0.703125, 0.237060547, 0.014556885, 0.014556885, 0.014556885, 0.014556885]

funcZ = [2.875, 0.703125, -0.20117, 0.237061, 0.014557, -0.09414, -0.04, -0.01278, 0.000877]

fig = plt.figure(figsize=(20,8))
ax  = fig.add_subplot(111)
ax.plot(t, x, c='b', label='x',linewidth=3.0)
ax.plot(t, y, c='r', label='y',linewidth=3.0)
ax.plot(t, z, c='g', label='z',linewidth=3.0)
ax.plot(t, funcX, c='y', label='funcX',linewidth=3.0)
ax.plot(t, funcY, c='k', label='funcY',linewidth=3.0)
ax.plot(t, funcZ, c='m', label='funcZ',linewidth=3.0)
plt.legend(fontsize = 'large')
plt.show()

# %%
# Out:
# [2, 1.5, 1.25, 1.25, 1.1875, 1.15625, 1.15625, 1.15625, 1.15625]

# %%
import numpy as np
import matplotlib.pyplot as plt

t = [1,2,3,4,5,6,7]

x = [1,1.5,1.5,1.625,1.6875,1.7188,1.7188]

y = [2 ,2 ,1.75, 1.75, 1.75, 1.75, 1.7344]

z = [1.5, 1.75 ,1.625, 1.6875, 1.7188, 1.7344, 1.7266]

funcX = [-2, -0.75, -0.75, -0.3594, -0.1523, -0.0457, -0.0457]

funcY = [1, 1, 0.0625, 0.0625, 0.0625, 0.0625, 0.0081]

funcZ = [-0.75, 0.062, -0.359, -0.1523, -0.0457, 0.0081, -0.0189]

fig = plt.figure(figsize=(20,8))
ax  = fig.add_subplot(111)
ax.plot(t, x, c='b', label='x',linewidth=3.0)
ax.plot(t, y, c='r', label='y',linewidth=3.0)
ax.plot(t, z, c='g', label='z',linewidth=3.0)
ax.plot(t, funcX, c='y', label='funcX',linewidth=3.0)
ax.plot(t, funcY, c='k', label='funcY',linewidth=3.0)
ax.plot(t, funcZ, c='m', label='funcZ',linewidth=3.0)
plt.legend(fontsize = 'large')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = [1,2,3]

x = [0.5, 0.693490148, 0.701329112]



funcXN = [0.693490148, 0.701329112, 0.701367855]

funcYN = [0.108635113, 0.000531374, 3.363*np.exp(-7)]

fig = plt.figure(figsize=(20,8))
ax  = fig.add_subplot(111)
ax.plot(t, x, c='b', label='x',linewidth=3.0)
ax.plot(t, funcXN, c='y', label='funcXN',linewidth=3.0)
ax.plot(t, funcYN, c='k', label='funcYN',linewidth=3.0)

plt.legend(fontsize = 'large')
plt.show()
