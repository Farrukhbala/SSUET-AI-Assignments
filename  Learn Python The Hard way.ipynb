# %% [markdown]
# <h2>                   Learn Python The Hard way</h2>

# %% [markdown]
# <h3> Exercise # 1 </h3>

# %%
print ("Hello World")
print ("Hello Again")
print("I like typing this")
print("This is fun")
print ("Yay! Printing.")
print("I'd much rather you 'not'.")
print ('I "said" don not touch this.')

#A comment, this is so you cab read your program Later
# Anthing after the # is ignored by python.

print("I could have code like this.") # and the comment after is ignored.

# You can also use a comment to "disable" or comment out a piece of code
#print "this won't run"

print("This will run")

# %% [markdown]
# <h3>Exercise No 2</h3>

# %%
                            #COMMENTS EXERCISE 2
#A comment, this is so you cab read your program Later
# Anthing after the # is ignored by python.

print("I could have code like this.") # and the comment after is ignored.

# You can also use a comment to "disable" or comment out a piece of code
#print "this won't run"

print("This will run.")

# %% [markdown]
# <h3>Exercise No 3</h3>

# %%
                    # NUMBERS AND MATH
# + For ADDITION
# - SUBTRACTION
# / DIVISION
# * ASTERISK IS FOR MULTIPLICATION
# % IS FOR MODULUS OR I WOULD SAY REMAINDER
# < LESS THAN SIGN
# > GREATER THAN SIGN
# <= LESS THAN EQUAL TO
# >= GREATER THAN EQUAL TO

print ("I will now count the chickens:") # THIS LINE IS WILL JUST PRINT THE TEXT

print ("Hens",25 - 30 / 6) 

# THIS LINE WILL PRINT "Hens" AND
#IT WILL CALCULATE AND WILL GIVE THE ANSWER OF 25 MINUS 30 DIVIDED BY 6
#THAT IS EQUAL TO 20
print ("Roosters", 100 - 25 * 3 % 4)    

# THIS LINE WILL PRINT "ROSSTERS" AND
#IT WILL CALCULATE
#AND will GIVE THE ANSWER OF 100 MINUS 25 MULTIPLY BY 3 AND MODULUS OF 4

print ("Now I will count the eggs:")

print (3 + 2 + 1 - 5 + 4 % 2 - 1 / 4 + 6)

print ("Is it true that 3 + 2 < 7:")

print (3 + 2 < 5 - 7)

print ("What is 3 + 2?", 3 + 2)

print ("What is 5 - 7?", 5 - 7)

print ("Oh, that's why it's False.")

print ("How about some more.")

print ("Is it greater?", 5 > -2)

print ("Is it greater or equal?",5 >= -2)

print ("Is it less or equal?", 5 <= -2)

# %% [markdown]
# <h3>Exercise 4</h3>

# %%
                # EXERCISE 4 VARIABLE AND NAMES

cars = 100
space_in_a_car = 4.0
drivers = 30
passsengers = 90
cars_not_driven = cars - drivers
cars_driven = drivers
carpool_capacity = cars_driven * space_in_a_car
average_passengers_per_car = passsengers / cars_driven




print ("There are", cars, "cars available.")
print ("There are only", drivers, "drivers available")
print ("There will be", cars_not_driven, "empty cars today.")
print ("We can transport", carpool_capacity, "people today.")
print ("We have", passsengers, "to carpool today.")
print ("We need to put about", average_passengers_per_car, "in each car.")


# When I was doing this Exercise for the first time I had a mistake
# There are 100 cars available.
# There are only
# Traceback (most recent call last):
# File "ex4.py", line 16, in <module>
# print "There are only", driver, "drivers available"
# NameError: name 'driver' is not defined

# Comment below and tell me what I did wrong ?
# Try to use python as a calculator.

# %% [markdown]
# <h3>Exercise No 5</h3>

# %%
                # EXERCISE 5 MORE VARIABLES AND NAMES
my_name = 'farrukh khan'
my_age = 24 #Not a lie
my_height = 74 # inches
my_weight = 180 # lbs
my_eyes = 'black'
my_teeth = 'white'
my_hair = 'black'

print ("Let's talk about %s." % my_name)
print ("He's %d inches tall." % my_height)
print ("He's %d pounds heavy." % my_weight)
print ("Actually that's not too heavy.")
print ("He's got %s eyes and %s hair."% (my_eyes, my_hair))
print ("his teeth are usually %s depending on the coffee." % my_teeth)

# This line will be tricky, try to get it exactly right
print ("If I add %d, %d, and %d I get %d." % (my_age, my_height, my_weight,my_age + my_height + my_weight))

# %% [markdown]
# <h3>Exercise No 6</h3>

# %%
                # EXERCISE 6 STRINGS AND TEXT

x = "there are %d types of people." % 10 

# This line is assigning the x
#where format specifier %d is used to put 10 into the statement

binary = "binary" # Assigning binary variable equal to "binary"
#you can assign anything

do_not = "don't" # Same as the above statement

y = "Those who know %s and those who %s." % (binary, do_not) 

# Assigning and
#completing the the sentence using format specifiers and 
#we have used %s format specifier because we want to print string in it.

print (x) # Printing x variable
print (y) # Printing y variable

print ("I said: %r." % x) 

# printing the raw material of the x variable becasue
#the %r format specifier is used for showing the raw material
#and %r format specifier is used for debugging

print ("I also said: '%s'." % y) 

# Doing the same thing as the above
#command but printing the string of the variable y.

hilarious = False     

# Assigning the boolean expression to the variable
#hilarious.

joke_evaluation = "Isn't that joke so funny?! %r"
print (joke_evaluation % hilarious)

w = "This is the left side of..."
e = "a string with a right side."
print (w + e)

# %% [markdown]
# <h3>Exercise No 7</h3>

# %%
                # EXERCISE 7 MORE PRINTING

print ("Mary had a little lamb.")
print ("Its fleece was white as %s." % 'snow')
print ("And everywhere that Mary went.")
print ("." * 10) # This statemnt will multiply the dot 10 times

# Assigning twelwe variables as cheesBuger

end1 = "C"
end2 = "h"
end3 = "e"
end4 = "e"
end5 = "s"
end6 = "e"
end7 = "B"
end8 = "u"
end9 = "r"
end10 = "g"
end11 = "e"
end12 = "r"
# what that comma at the end. try removing it to see waht happens

print (end1 + end2 + end3 + end4 + end5 + end6, end=' ') # This comma
#will merge the lower command into one and than it will print chees Buger 
#we have put comma now it will add one space in between the letters
print (end7 + end8 + end9 + end10 + end11 + end12)

# %% [markdown]
# <h3>Exercise No 8</h3>

# %%
                # EXERCISE 8 PRINTING, PRINTING, PRINTING

formatter = "{} {} {} {}"

print (formatter.format(1, 2, 3, 4))
print (formatter.format ("one", "two", "three", "four"))
print (formatter.format(True, False, True, False))
print (formatter.format(formatter, formatter, formatter, formatter))
print (formatter.format(
        "I had this thing.",
        "That you could up right.",
        "BUt it didn't sing.",
        "So I said goodnight."
                ))

# %% [markdown]
# <h3>Exercise No 9</h3>

# %%
                # EXERCISE 9 MORE PRINTING, PRINTING, PRINTING

# Here is the some new strange stuff, remeber type it exactly


days = "Mon Tue Wed Thu Fri Sat Sun"
months = "\nJan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug\a"

print ("\vHere are the days: ", days)
print ("Here are the months: ", months)

print ('''
There's something going on here.
With the three double-qoutes.
We'll be able to type as much as we like.
Even 4 lines if we want, or 5, or 6.
''' )

# %% [markdown]
# <h3>Exercise No 10</h3>

# %%
                # EXERCISE 10 ESCAPE SEQUENCES


tabby_cat = "\tI'm tabbed in."
persian_cat = "I'm split\non a line."
backslash_cat = "I'm \\ a \\ cat."

fat_cat = """
I will do a list:
\t* Cat food
\t* Fishies
\t* Catnip\n\t* Grass
"""

print (tabby_cat)
print (persian_cat)
print (backslash_cat)
print (fat_cat)

# %% [markdown]
# <h3>Exercise No 11</h3>

# %%
                # EXERCISE 11 ASKING QUESTIONS TAKING INPUT FROM USERS
print("How old are you?",end=' ')
age = input()
print ("How tall are you?", end=' ')
height = input()
print ("How much do you weigh?", end=' ')
weight = input()

print (f"So, you're {age} old, {height} tall and {weight} heavy.")

# %% [markdown]
# <h3>Exercise No 12</h3>

# %%
                # EXERCISE 12 PREVIOUS EXERCISE WITH LITTLE ADVANCE METHOD

age = input("How old are you? ")
height = input("How tall are you? ")
weight = input("How to much do you weigh? ")

print (f"So, you're {age} old, {height} tall and {weight} heavy. ")

# %% [markdown]
# <h3>Exercise No 13</h3>

# %%
                # EXERCISE 13 ONE MORE INPUT METHOD
from sys import argv

script, first, second = argv

print ("The script is called:", script) # This script variable will print the python file name
print ("Your first variable is:", first) # This will be the first input.
print ("YOur second variable is:", second) # This will be the second input.


# You have to give all three input otherwise you will get error.
# YOu can actually give any inputs but they have to be three arguments
# Out:
# The script is called: C:\Users\Zodiac\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py
# Your first variable is: -f
# YOur second variable is: C:\Users\Zodiac\AppData\Roaming\jupyter\runtime\kernel-3c51dc67-47c8-44ac-bee6-6c4087d49886.json

# %% [markdown]
# <h3>Exercise No 14</h3>

# %%
                # EXERCISE 14 PROMPTING AND PASSING


from sys import argv

scripts, user_name= argv[0],argv[1]
prompt = '> '

print(f"Hi {user_name}, I'm the {script} script.")
print ("I'd like to ask you a few questions.")
print (f"Do you like me {user_name}?")

likes = input(prompt)

print(f"Where do you live {user_name}")
lives = input(prompt)

print("What kind of computer do you have?")
computer = input(prompt)

print(f"""ALright, so you said {likes} about liking me.
YOu live in {lives}. Not sure where that is.
And you have a {computer}. Nice""")
# Out:
# Hi -f, I'm the C:\Users\Zodiac\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py script.
# I'd like to ask you a few questions.
# Do you like me -f?
# > 100+ Python challenging programming exercises (1).txt
# Where do you live -f
# > no
# What kind of computer do you have?
# > no
# ALright, so you said 100+ Python challenging programming exercises (1).txt about liking me.
# YOu live in no. Not sure where that is.
# And you have a no. Nice

# %% [markdown]
# <h3>Exercise No 15</h3>

# %%
                # EXERCISE 15 READING FILES AND SAVING THEM


from sys import argv

script, filename = argv[0],argv[1]

txt = open(filename)

print("Here's your file %r: " % filename)
print(txt.read())

print("Type the filename again:")
file_again = input("> ")

txt_again = open(file_again)

print(txt_again.read())
# Out:
# Here's your file '-f':
# 1
# 2
# 3
#
# Type the filename again:
# > 100+ Python challenging programming exercises (1).txt
# 100+ Python challenging programming exercises
#
# 1.	Level description
# Level	Description
# Level 1	Beginner means someone who has just gone through an introductory Python course. He can solve some problems with 1 or 2 Python classes or functions. Normally, the answers could directly be found in the textbooks.
# Level 2	Intermediate means someone who has just learned Python, but already has a relatively strong programming background from before. He should be able to solve problems which may involve 3 or 3 Python classes or functions. The answers cannot be directly be found in the textbooks.
# Level 3	Advanced. He should use Python to solve more complex problem using more rich libraries functions and data structures and algorithms. He is supposed to solve the problem using several Python standard packages and advanced techniques.
#
# 2.	Problem template
#
# ...

# %% [markdown]
# <h3>Exercise No 16</h3>

# %%
                # EXERCISE 16 READING FILES WRITING FILES
                    # AND SAVING THEM LIKE A NOTEPAD

                    # MAKING A SIMPLE TEXT EDITOR


                    # FUNCTIONS TO REMEMBERS

# close --- CLoses the file.
# read  --- Reads the contents if the file.
# readline --- reads the one line.
# truncate --- Empties the file.
# write (stuff) --- write something to the file.


from sys import argv

script, filename = argv[0],argv[1]

print(f"We're going to create erase {filename}.")
print ("If you don't want that, hit CTRL-C (^C).")
print ("If you do want that, hit RETURN.")

input("?")

print("OPeneing the file....")
target = open(filename,'w')

print("truncating the file. Goodbye!")
target.truncate()

print("Now, I'm going to ask you for ten lines.")

line1 = input("Line 1: ")
line2 = input("Line 2: ")
line3 = input("Line 3: ")

print("I;m going to write these to the file.")

target.write(line1)
target.write("\n")
target.write(line2)
target.write("\n")
target.write(line3)
target.write("\n")

print("AND FINALLY, WE CLOSE IT.")
target.close()
# Out:
# We're going to create erase -f.
# If you don't want that, hit CTRL-C (^C).
# If you do want that, hit RETURN.
# ?100+ Python challenging programming exercises (1).txt
# OPeneing the file....
# truncating the file. Goodbye!
# Now, I'm going to ask you for ten lines.
# Line 1: 1
# Line 2: 2
# Line 3: 3
# I;m going to write these to the file.
# AND FINALLY, WE CLOSE IT.

# %% [markdown]
# <h3>Exercise No 17</h3>

# %%
                # EXERCISE 17 MORE PRACTICE OF FILES AND BUILD-IN FUNCTIONS

                    #VERY IMPORTANT PROGRAM IT MAKES FILES AND
                    # IT CAN ALSO SAVE ONE FILE TO THE OTHER


from sys import argv
from os.path import exists  #EXISTS return true if that file exists,
                                    #it returns FALSE if not.

script, from_file, to_file = argv[0],argv[1],argv[2]

print(f"Copying from {from_file} to {to_file}")

# we could do these two on one line, how? We have to find it later.

in_file = open('100+ Python challenging programming exercises (1).txt')
indata = in_file.read()

print(f"The input file is {len(indata)} bytes long")
# f is the format specifier
print(f"Does the output file exist? {exists(to_file)}")

print("Ready, hit RETURN to continue, CTRL-C to abort.")
input()

out_file = open(to_file, 'w')
out_file.write(indata)

print("Alright i'm all done")

out_file.close()
in_file.close()
# Out:
# Copying from -f to C:\Users\Zodiac\AppData\Roaming\jupyter\runtime\kernel-3c51dc67-47c8-44ac-bee6-6c4087d49886.json
# The input file is 51343 bytes long
# Does the output file exist? True
# Ready, hit RETURN to continue, CTRL-C to abort.
#
# Alright i'm all done

# %% [markdown]
# <h3>                # EXERCISE 18 Names, Variables, Code, Functions
#
#
# </h3>

# %%
#Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"

# This one is like your scripts with argv

def print_two(*args):
    arg1, arg2 = args
    print (f"agr1: {arg1}, arg2: {arg2}")

# OK, that *args is actually pointless, we can just do This

def print_two_again(arg1, arg2):
    print (f"arg1: {arg1}, arg2: {arg2}")


#This just takes one argument

def print_one(arg1):
    print (f"arg1: {arg1}")

#This one takes no arguments

def print_none():
    print ("I got nothin'")

print_two("farrukh","khan")
print_two_again("farrukh", "khan")
print_one("one argument")
print_none()
# Out:
# agr1: farrukh, arg2: khan
# arg1: farrukh, arg2: khan
# arg1: one argument
# I got nothin'

# %% [markdown]
# <h3>Exercise No 19 </h3>

# %%
                # EXERCISE 19 FUNCTIONS AND VARIABLES

                #Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"

def cheese_and_crackers(cheese_count, boxes_of_crackers):

    print ("You have {}!".format(cheese_count))
    print (f"You have {boxes_of_crackers}")
    print ("Man that's enough for a party!")
    print ("Get a blanket.\n")

print ("We can just give the function numbers directly:")
cheese_and_crackers(20, 30)

print("OR, We can use variables from our script :")

amount_of_cheese = 10
amount_of_crackers = 50

cheese_and_crackers(amount_of_cheese,amount_of_crackers)

print ("We can even do math inside too:")
cheese_and_crackers(10 + 20, 5 + 6)

print ("And we can combine the two, variables and math:")
cheese_and_crackers(amount_of_cheese + 100, amount_of_crackers + 1000)
# Out:
# We can just give the function numbers directly:
# You have 20!
# You have 30
# Man that's enough for a party!
# Get a blanket.
#
# OR, We can use variables from our script :
# You have 10!
# You have 50
# Man that's enough for a party!
# Get a blanket.
#
# We can even do math inside too:
# You have 30!
# You have 11
# Man that's enough for a party!
# Get a blanket.
#
# And we can combine the two, variables and math:
# You have 110!
# You have 1050
# Man that's enough for a party!
# Get a blanket.

# %% [markdown]
# <h3>Exercise No 20</h3>

# %%
                # EXERCISE 20 FUNCTIONS AND FILES

                #Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"


from sys import argv
script, input_file = argv[0],argv[1]

def print_all(f):
    print (f.read())

def rewind(f):
    f.seek(0)

def print_a_line(line_count, f):
    print (line_count,f.readline())

current_file = open('100+ Python challenging programming exercises (1).txt')

print ("First let's print the file:\n")

print_all(current_file)

print ("Now let's rewind, kind of like a tape.")

rewind(current_file)

print("Let's print three lines")

current_line = 1
print_a_line(current_line, current_file)

current_line += 1
print_a_line (current_line,current_file)

current_line  += 1
print_a_line(current_line, current_file)
# Out:
# First let's print the file:
#
# 100+ Python challenging programming exercises
#
# 1.	Level description
# Level	Description
# Level 1	Beginner means someone who has just gone through an introductory Python course. He can solve some problems with 1 or 2 Python classes or functions. Normally, the answers could directly be found in the textbooks.
# Level 2	Intermediate means someone who has just learned Python, but already has a relatively strong programming background from before. He should be able to solve problems which may involve 3 or 3 Python classes or functions. The answers cannot be directly be found in the textbooks.
# Level 3	Advanced. He should use Python to solve more complex problem using more rich libraries functions and data structures and algorithms. He is supposed to solve the problem using several Python standard packages and advanced techniques.
#
# 2.	Problem template
#
# #----------------------------------------#
# Question
# Hints
# Solution
#
# 3.	Questions
#
# ...

# %% [markdown]
# <h3>Exercise No 21</h3>

# %%
                # EXERCISE 21 FUNCTIONS CAN RETURN SOMETHING

                #Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"


                # MAKING THE SIMPLE CALCULATOR USING FUNCTIONS
                    #    +  *  /  -


def add(a, b):
    print (f"ADDING {a} + {b}\n")
    return a + b

def sub(a, b):
    print (f"SUBTRACTING {a} - {b}\n")
    return a - b

def multiply(a, b):
    print (f"MULTIPLICATION {a} * {b}\n")
    return a * b

def divide(a, b):
    print (f"DIVISION {a} / {b}\n")
    return a / b

print("Let's do some math with just functions!")

age = add(10,14)
height = sub(70,20)
weight = multiply(90,2)
iq = divide(100, 2)
power = pow(10,2)

print("Age: {}, Height: {}, Weight: {}, IQ: {}, Power: {}\n".format(age,height,weight,iq,power))

# A puzzle for extra credit, type it anyway.

print("Here is a puzzle.")

what = add(age,sub(height,multiply(weight,divide(iq,2))))

print("That becomes: ",what, "Can you it by hand?")
# Out:
# Let's do some math with just functions!
# ADDING 10 + 14
#
# SUBTRACTING 70 - 20
#
# MULTIPLICATION 90 * 2
#
# DIVISION 100 / 2
#
# Age: 24, Height: 50, Weight: 180, IQ: 50.0, Power: 100
#
# Here is a puzzle.
# DIVISION 50.0 / 2
#
# MULTIPLICATION 180 * 25.0
#
# SUBTRACTING 50 - 4500.0
#
# ADDING 24 + -4450.0
#
# That becomes:  -4426.0 Can you it by hand?

# %% [markdown]
# <h3>Exercise No 22</h3>

# %%
                # EXERCISE 24 MORE PRACTICE ON FUNCTIONS

                #Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"

print ("Let's practice everything.")
print("You\'d need to know \'bout escapes with \\ that do \n newlines and \t tabs." )

poem = """
\tThe lovely world
with logic so firmly planted
cannot discern \n the needs of lovelynor comprehend passion from intuition
and requires an explaination
\n\t\twhere there is none.
"""
print("\t---------------------")
print (poem)
print("\t---------------------")

five = 10 - 2 + 3 - 6
print(f"This should be five: {five}")

def secret_formula(started):
    jelly_beans = started * 500
    jars  = jelly_beans / 1000
    crates = jars / 100
    return jelly_beans, jars, crates


start_point = 10000
beans, jars, crates = secret_formula(start_point)

print(f"With a starting point of: {start_point}")
print(f"We'd have {beans} beans, {jars} jars and {crates} crates.")

start_point = start_point / 10
print("We can also do that way:")

formula = secret_formula(start_point)
# This is an easy way to apply a list to a format stirng
print("We'd have {} beans, {} jars, and {} crates.".format(*formula))
# Out:
# Let's practice everything.
# You'd need to know 'bout escapes with \ that do
#  newlines and 	 tabs.
# 	---------------------
#
# 	The lovely world
# with logic so firmly planted
# cannot discern
#  the needs of lovelynor comprehend passion from intuition
# and requires an explaination
#
# 		where there is none.
#
# 	---------------------
# This should be five: 5
# With a starting point of: 10000
# We'd have 5000000 beans, 5000.0 jars and 50.0 crates.
# We can also do that way:
# We'd have 500000.0 beans, 500.0 jars, and 5.0 crates.

# %% [markdown]
# <h3>Exercise No 25</h3>

# %%
                # EXERCISE 25 EVEN MORE PRACTICE

                #Always remember Functions do three simple things
                #  1. They have a piece of code with a name
                #  2. They take arguments and some may not.
                #  3. They let you make "mini-script"

def break_words(stuff):
    """This function will break up words for us."""
    words = stuff.split(' ')
    return words

def sort_words(words):
    """Sorts the words"""
    return sorted(words)

def print_first_word(words):
    """Prints the first word after popping it off."""
    word = words.pop(0)
    print(word)

def print_last_word(words):
    """Prints the first word after popping it off"""
    word = words.pop(-1)
    print(word)

def sort_sentence(sentence):
    """"Takes in a full sentence and returns the worted words """
    words = break_words(sentence)
    return sort_words(words)

def print_first_and_last(sentence):
    """Print the first and last words of the sentence. """
    words = break_words(sentence)
    print_last_word(words)
    print_first_word(words)

def print_first_and_last_sorted(sentence):
    """ Sorts the word then prints the and last one. """
    words = sort_sentence(sentence)
    print_first_word(words)
    print_last_word(words)

# %% [markdown]
# <h3>Exercise No 26</h3>

# %%
                # EXERCISE 26 TAKING A TEST!
print("How old are you?", end=' ')
age = input()
print("How tall are you?", end=' ')
height = input()
print("How much do you weigh?", end=' ')
weight = input()

print(f"So, you're {age} old, {height} tall and {weight} heavy.")

from sys import argv
script, filename = argv[0],argv[1]

txt = open(filenme)

print("Here's your file {filename}:")
print(tx.read())

print("Type the filename again:")
file_again = input("> ")

txt_again = open(file_again)

print(txt_again_read())


print("Let's practice everything.")
print('You\'d need to know \'bout escapes with \\ that do \n newlines and \t tabs.')

poem = """
\tThe lovely world
with logic so firmly planted
cannot discern \n the needs of love
nor comprehend passion from intuition
and requires an explanation
\n\t\twhere there is none.
"""

print("--------------")
print(poem)
print("--------------")


five = 10 - 2 + 3 - 6
print(f"This should be five: {five}")


def secret_formula(started):
    jelly_beans = started * 500
    jars = jelly_beans / 1000
    crates = jars / 100
    return jelly_beans, jars, crates


start_point = 10000
beans, jars, crates = secret_formula(start_point)

# remember that this is another way to format a string
print("With a starting point of: {}".format(start_point))
# it's just like with an f"" string
print(f"We'd have {beans} beans, {jars} jars, and {crates} crates.")

start_point = start_point / 10

print("We can also do that this way:")
formula = secret_formula(start_point)
# this is an easy way to apply a list to a format string
print("We'd have {} beans, {} jars, and {} crates.".format(*formula))



people = 20
cats = 30
dogs = 15


if people < cats:
    print ("Too many cats! The world is doomed!")

if people < cats:
    print("Not many cats! The world is saved!")

if people < dogs:
    print("The world is drooled on!")

if people > dogs:
    print("The world is dry!")


dogs += 5

if people >= dogs:
    print("People are greater than or equal to dogs.")

if people <= dogs:
    print("People are less than or equal to dogs.")


if people == dogs:
    print("People are dogs.")
# Out:
# How old are you? 24
# How tall are you? 74
# How much do you weigh? 80
# So, you're 24 old, 74 tall and 80 heavy.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-305905281dcd> in <module>()
#      12 script, filename = argv[0],argv[1]
#      13
# ---> 14 txt = open(filenme)
#      15
#      16 print("Here's your file {filename}:")
#
# NameError: name 'filenme' is not defined

# %%
from sys import argv
sys.argv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-ca7bc6c69f42> in <module>()
#       1 from sys import argv
# ----> 2 sys.argv
#
# NameError: name 'sys' is not defined
