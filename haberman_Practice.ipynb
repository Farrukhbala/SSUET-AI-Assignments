# %% [markdown]
# <a href="https://colab.research.google.com/github/Farrukhbala/SSUET-AI-Assignments/blob/master/haberman_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fdurant/suplearn_challenges/master/haberman.csv')
df.columns = ['age',	'operation_year',	'axil_nodes'	,'status']

# %%
df.head()
# Out:
#    age  operation_year  axil_nodes  status
# 0   30              64           1       1
# 1   30              62           3       1
# 2   30              65           0       1
# 3   31              59           2       1
# 4   31              65           4       1

# %%
df.tail()
# Out:
#      age  operation_year  axil_nodes  status
# 301   75              62           1       1
# 302   76              67           0       1
# 303   77              65           3       1
# 304   78              65           1       2
# 305   83              58           2       2

# %%
df.describe()
# Out:
#               age  operation_year  axil_nodes      status
# count  306.000000      306.000000  306.000000  306.000000
# mean    52.457516       62.852941    4.026144    1.264706
# std     10.803452        3.249405    7.189654    0.441899
# min     30.000000       58.000000    0.000000    1.000000
# 25%     44.000000       60.000000    0.000000    1.000000
# 50%     52.000000       63.000000    1.000000    1.000000
# 75%     60.750000       65.750000    4.000000    2.000000
# max     83.000000       69.000000   52.000000    2.000000

# %%
print('Minimum ',df[['age']].min())
print('Maximum ',df[['age']].max())
# Out:
# Minimum  age    30
# dtype: int64
# Maximum  age    83
# dtype: int64

# %%
print(df[['operation_year']].min())
print(df[['operation_year']].max())
# Out:
# operation_year    58
# dtype: int64
# operation_year    69
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'operation_year', 'axil_nodes', 'status'], dtype='object')

# %%
print(df['status'].value_counts())
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
print("total people survied more than 5 years= ",f'{(225/306)*100}')
# Out:
# total people survied more than 5 years=  73.52941176470588

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('whitegrid')
sns.pairplot(df, hue = 'status',size=3 )
plt.show()

# %%
sns.FacetGrid(df , hue = 'status', size = 8).map(sns.distplot , 'axil_nodes').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.boxplot(data = df  ,x ='status',y='operation_year')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(data = df, x = 'status' , y = 'age')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(data = df, x = 'status', y = 'axil_nodes')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.violinplot(data = df, x = 'status' , y = 'operation_year')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.violinplot(data = df, x = 'status', y = 'age')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.violinplot(data = df, x = 'status', y = 'axil_nodes')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”

sns.jointplot(x=df["age"], y=df["axil_nodes"], kind='kde')
# sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='hex')
# sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='kde')

plt.show()

# %%
sns.jointplot(x=df["status"], y=df["age"], kind='kde')
plt.show()

# %%
sns.jointplot(x=df["age"], y=df["operation_year"], kind='kde')

# %%
df1 = df[df['axil_nodes'] >= 5]

df1.describe()
# Out:
#              age  operation_year  axil_nodes     status
# count  76.000000       76.000000   76.000000  76.000000
# mean   51.092105       63.013158   13.671053   1.513158
# std     9.703852        3.160141    8.953790   0.503148
# min    33.000000       58.000000    5.000000   1.000000
# 25%    44.000000       60.750000    7.000000   1.000000
# 50%    52.500000       63.000000   11.000000   2.000000
# 75%    57.500000       65.000000   18.250000   2.000000
# max    70.000000       69.000000   52.000000   2.000000

# %%
df[df['axil_nodes'] <= 5].plot(x='age', y=['status', 'axil_nodes'], figsize=(10,5), grid=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# # Final Conclusion

# %% [markdown]
# **1. Those who are having more than five axil_nodes they less chance of surviving the cancer.**
#
# **2. Age also does matter, having cancer at the age of 50 or above there is minimal chance of surviving the cancer.**
#
# **3. having more than five axil_nodes people tend to survive less as compare to having less nodes.**
#
# **4. We cannot compare age with operation year as they overlapp in each other. **

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df.head()
# Out:
#    age  operation_year  axil_nodes  status
# 0   30              64           1       1
# 1   30              62           3       1
# 2   30              65           0       1
# 3   31              59           2       1
# 4   31              65           4       1

# %%
predict_y = df['status'].values
features_x = df[names].values

# %%
from sklearn.model_selection import

# %%
X_train, X_test, y_train, y_test = train_test_split(features_x, predict_y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predict = clf.predict(X_test)

# %%
plt.scatter(y_test, predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
print("Score", clf.score(X_test, y_test))
# Out:
# Score 0.6413043478260869

# %%
print("Score", clf.score(X_train, y_train))
# Out:
# Score 0.985981308411215
